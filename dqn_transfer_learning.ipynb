# %%
# %%
# %matplotlib inline

# %%
# %%
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import os
import pathlib

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from dataset import rf_env

dataset_dir = "../dataset/DataCollection0/"
save_dir = "experiments/experiment_1"

env = rf_env(dataset_dir)
pathlib.Path(save_dir).mkdir(parents=True, exist_ok=True)

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if GPU is to be used
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
# %%
class DQN_Conv(nn.Module):

    def __init__(self, n_observations, n_statistics, n_actions):
        super(DQN_Conv, self).__init__()
        self.conv1 = nn.Conv2d(2, 64, kernel_size=(1, 5), stride=1, padding=(0, 2))
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=(1, 5), stride=1, padding=(0, 2))
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 64, kernel_size=(1, 5), stride=1, padding=(0, 2))
        self.bn3 = nn.BatchNorm2d(64)
        self.flatten = nn.Flatten()
        self.regression = nn.Linear(n_observations * 64, n_statistics)
        self.fc1 = nn.Linear(n_observations * 64, 128)
        self.fc2 = nn.Linear(128, n_actions)
        self.mode = 'regression'

    def change_mode(self, mode):
        self.mode = mode

    def freeze_backbone(self):
        for param in self.parameters():
            param.requires_grad = False
        for param in self.fc1.parameters():
            param.requires_grad = True
        for param in self.fc2.parameters():
            param.requires_grad = True

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)

        x = self.flatten(x)

        if self.mode == 'regression':
            x = self.regression(x)
        elif self.mode == 'policy':
            x = F.relu(self.fc1(x))
            x = self.fc2(x)

        return x

# %%
# %%

class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 1024
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 10000
TAU = 0.005
LR = 1e-4

# Get number of actions from the RF environment
n_actions = env.n_actions
# Get the number of state observations
state, _ = env.reset()
# FIXME: return signal power and snrs instead of preamble IQ symbols
n_observations = state.shape[-1]

# FIXME: return signal power and snrs instead of preamble IQ symbols
policy_net = DQN_Conv(n_observations, 2, n_actions).to(device)
target_net = DQN_Conv(n_observations, 2, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(100000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        return torch.tensor([[random.randint(0, env.n_actions - 1)]], device=device, dtype=torch.long)


cumulative_rewards = dict()


def plot_cumulative_reward(show_result=False):
    fig = plt.figure()
    cumulative_rewards_t = dict()
    for reward_key in cumulative_rewards.keys():
        cumulative_rewards_t[reward_key] = torch.tensor(cumulative_rewards[reward_key], dtype=torch.float)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Cumulative Rewards')
    for reward_key in cumulative_rewards_t.keys():
        plt.plot(cumulative_rewards_t[reward_key].numpy())
        n_episodes = len(cumulative_rewards_t[reward_key])
    # Take 100 episode averages and plot them too
    if n_episodes >= 100:
        for reward_key in cumulative_rewards_t.keys():
            if reward_key == 'Total': # Just plot the average of the total cumulative reward
                means = cumulative_rewards_t[reward_key].unfold(0, 100, 1).mean(1).view(-1)
                # means = torch.cat((torch.zeros(99), means))
                plt.plot(means.numpy())

    plt.legend([*list(cumulative_rewards_t.keys()), 'mean'])
    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())
    
    return fig

# %%
preambles_dict = rf_env.load_all_preambles(dataset_dir)

preambles = np.stack([preambles_dict[key] for key in preambles_dict.keys()])
statistics = np.stack([np.array([float(key.split("_")[0]), float(key.split("_")[1])]) for key in preambles_dict.keys()])

preambles = torch.tensor(preambles, dtype=torch.float)
statistics = torch.tensor(statistics, dtype=torch.float)
print(preambles.shape)
print(statistics.shape)
# Out:
# torch.Size([378, 2, 1, 2176])
# torch.Size([378, 2])

# %%
from torch.utils.data import TensorDataset, DataLoader

policy_net.change_mode('regression')

ds_regression = TensorDataset(preambles, statistics)
dl_regression = DataLoader(ds_regression, batch_size=BATCH_SIZE, shuffle=True, num_workers=16)

loss_regression = torch.nn.MSELoss()
optimizer_regression = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)

running_loss = []

for epoch in range(50):
    running_loss.append(0)
    for X, y in dl_regression:
        X = X.to(device)
        y = y.to(device)
        pred = policy_net(X)
        optimizer.zero_grad()
        loss = loss_regression(pred, y)
        loss.backward()
        optimizer.step()
        running_loss[-1] += loss.item()

plt.plot(running_loss)
# Out:
# /home/microway/anaconda3/envs/mabdi-radiortml/lib/python3.12/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at /opt/conda/conda-bld/pytorch_1712609048481/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,

# %%
target_net.load_state_dict(policy_net.state_dict())

policy_net.change_mode('policy')
policy_net.freeze_backbone()
target_net.change_mode('policy')
target_net.freeze_backbone()

# %%
# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 1024
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 10000
TAU = 0.005
LR = 1e-4

# Get number of actions from the RF environment
n_actions = env.n_actions
# Get the number of state observations
state, _ = env.reset()
# FIXME: return signal power and snrs instead of preamble IQ symbols
n_observations = len(state)

# FIXME: return signal power and snrs instead of preamble IQ symbols
policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(100000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        return torch.tensor([[random.randint(0, env.n_actions - 1)]], device=device, dtype=torch.long)


cumulative_rewards = dict()


def plot_cumulative_reward(show_result=False):
    fig = plt.figure()
    cumulative_rewards_t = dict()
    for reward_key in cumulative_rewards.keys():
        cumulative_rewards_t[reward_key] = torch.tensor(cumulative_rewards[reward_key], dtype=torch.float)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Cumulative Rewards')
    for reward_key in cumulative_rewards_t.keys():
        plt.plot(cumulative_rewards_t[reward_key].numpy())
        n_episodes = len(cumulative_rewards_t[reward_key])
    # Take 100 episode averages and plot them too
    if n_episodes >= 100:
        for reward_key in cumulative_rewards_t.keys():
            if reward_key == 'Total': # Just plot the average of the total cumulative reward
                means = cumulative_rewards_t[reward_key].unfold(0, 100, 1).mean(1).view(-1)
                # means = torch.cat((torch.zeros(99), means))
                plt.plot(means.numpy())

    plt.legend([*list(cumulative_rewards_t.keys()), 'mean'])
    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())
    
    return fig

# %%
# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
# %%
if torch.cuda.is_available():
    num_episodes = 1000
else:
    num_episodes = 50

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, _ = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)

    cumulative_reward = {'Total': 0,
                        'rmsEVM': 0,
                        'Power': 0,
                        'BER': 0,
                        'rmsEVM_Normalized': 0,
                        'Power_Normalized': 0}

    for t in count():
        # print(state.shape)
        action = select_action(state)
        observation, reward, terminated, measures = env.step(action.item())
        for reward_key in cumulative_reward.keys():
            if reward_key == 'Total':
                cumulative_reward[reward_key] += reward
                continue
            cumulative_reward[reward_key] += measures[reward_key]
        
        reward = torch.tensor([reward], device=device)
        done = terminated

        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)

        if i_episode == 0:
            for reward_key in cumulative_reward.keys():
                cumulative_rewards[reward_key] = []

        if done:
            for reward_key in cumulative_reward.keys():
                cumulative_rewards[reward_key].append(cumulative_reward[reward_key])
            # plot_cumulative_reward()
            break

print('Complete')
fig = plot_cumulative_reward(show_result=True)
plt.ioff()
plt.show()
fig.savefig(os.path.join(save_dir, "train_cumulative_rewards.pdf"))
# Out:
# Complete

# %%
# %%
fig = plot_cumulative_reward(show_result=True)
plt.ioff()
plt.show()

# %%
# %%
torch.save(cumulative_rewards, os.path.join(save_dir, "train_cumulative_rewards.pt"))
torch.save(policy_net.state_dict(), os.path.join(save_dir, "policy_state.pt"))
torch.save(policy_net, os.path.join(save_dir, "policy.pt"))

# %%
# %%
policy_net.load_state_dict(torch.load(os.path.join(save_dir, "policy_state.pt")))
cumulative_rewards = torch.load(os.path.join(save_dir, "train_cumulative_rewards.pt"))

# %%
# Adjacent subplots with the same x axis

import scienceplots
import numpy as np

plt.style.use(['science','ieee'])

# %%

num_episodes = 3
cumulative_rewards_test = []
signal_powers = []
snrs = []
EVMs = []
powers = []
BERs = []
EVMs_Normalized = []
powers_Normalized = []
BERs_Normalized = []
lna_currents = []
mixer_currents = []

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, _ = env.reset(keep_last_config=True)
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)

    # print(f"Signal Power: {signal_powers[-1]}\tSNR: {snrs[-1]}")

    cumulative_reward_test = 0

    for t in count():
        signal_powers.append(env.comm_config.SignalPower)
        snrs.append(env.comm_config.SNR)

        with torch.no_grad():
            action = policy_net(state).max(1).indices.view(1, 1)
        observation, reward, terminated, measures = env.step(action.item())
        lna_currents.append(env.getLNACurrent())
        mixer_currents.append(env.getMixerCurrent())

        cumulative_reward_test += reward
        EVMs.append(measures['rmsEVM'])
        powers.append(measures['Power'])
        BERs.append(measures['BER'])
        EVMs_Normalized.append(measures['rmsEVM_Normalized'])
        powers_Normalized.append(measures['Power_Normalized'])
        BERs_Normalized.append(measures['BER'])
        
        done = terminated
        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Move to the next state
        state = next_state

        if done:
            cumulative_rewards_test.append(cumulative_reward_test)
            break

# plt.figure()
# plt.subplot(4, 1, 1)
# plt.plot(lna_currents)
# plt.title("LNA Current")
# plt.subplot(4, 1, 2)
# plt.plot(mixer_currents)
# plt.title("Mixer Current")
# plt.subplot(4, 1, 3)
# plt.plot(EVMs)
# plt.title("EVM")
# plt.subplot(4, 1, 4)
# plt.plot(powers)
# plt.title("Power Consumption")
# plt.show()

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
cumulative_rewards_test = np.array(cumulative_rewards_test, dtype=np.float32)
signal_powers = np.array(signal_powers, dtype=np.float32)
snrs = np.array(snrs, dtype=np.float32)
EVMs = np.array(EVMs, dtype=np.float32)
powers = np.array(powers, dtype=np.float32)
BERs = np.array(BERs, dtype=np.float32)
EVMs_Normalized = np.array(EVMs_Normalized, dtype=np.float32)
powers_Normalized = np.array(powers_Normalized, dtype=np.float32)
BERs_Normalized = np.array(BERs_Normalized, dtype=np.float32)
lna_currents = np.array(lna_currents, dtype=np.float32)
mixer_currents = np.array(mixer_currents, dtype=np.float32)
def heaviside(x):
    x[np.diff(x, prepend=x[0]) != 0] = np.nan
    return x

plt.figure()
fig_state, axs_state = plt.subplots(2, 1, sharex=True)
fig_state.subplots_adjust(hspace=0)
discontinuity_idx = np.diff(signal_powers).nonzero()[0]
for i in discontinuity_idx:
    axs_state[0].plot([discontinuity_idx + 1, discontinuity_idx + 1], [signal_powers[discontinuity_idx], signal_powers[discontinuity_idx + 1]], 'b--')
axs_state[0].plot(heaviside(signal_powers), 'b')
axs_state[0].set_xlim((0, num_episodes * rf_env.MaxSteps))
# axs_state[0].ylim(())
axs_state[0].grid(True)
# axs_state[0].xlabel("Step", fontsize=12)
axs_state[0].set_ylabel("Signal Power\n(dB)", fontsize=12)
# axs_state[0].legend([], fontsize=12)
# axs_state[0].xticks(fontsize=10)
axs_state[0].set_yticks(rf_env.SignalPower_List)
axs_state[0].tick_params(axis='both', labelsize=10)
discontinuity_idx = np.diff(snrs).nonzero()[0]
for i in discontinuity_idx:
    axs_state[1].plot([discontinuity_idx + 1, discontinuity_idx + 1], [snrs[discontinuity_idx], snrs[discontinuity_idx + 1]], 'b--')
axs_state[1].plot(heaviside(snrs), 'b')
axs_state[1].set_xlim((0, num_episodes * rf_env.MaxSteps))
# axs_state[1].ylim(())
axs_state[1].grid(True)
axs_state[1].set_xlabel("Step", fontsize=12)
axs_state[1].set_ylabel("SNR\n(dB)", fontsize=12)
# axs_state[1].legend([], fontsize=12)
# axs_state[1].xticks(fontsize=10)
axs_state[1].set_yticks(rf_env.SNR_List)
axs_state[1].tick_params(axis='both', labelsize=10)
# plt.rcParams["figure.titlesize"] = 14
fig_state.suptitle("Communication Environment Params", size=14)
plt.show()
fig_state.savefig(os.path.join(save_dir, "CommEnvParams_Random.pdf"))
fig_state.savefig(os.path.join(save_dir, "CommEnvParams_Random.png"))

plt.figure()
fig_action, axs_action = plt.subplots(2, 1, sharex=True)
fig_action.subplots_adjust(hspace=0)
discontinuity_idx = np.diff(lna_currents).nonzero()[0]
for i in discontinuity_idx:
    axs_action[0].plot([discontinuity_idx + 1, discontinuity_idx + 1], [lna_currents[discontinuity_idx], lna_currents[discontinuity_idx + 1]], 'g--')
axs_action[0].plot(heaviside(lna_currents), 'g')
axs_action[0].set_xlim((0, num_episodes * rf_env.MaxSteps))
# axs_action[0].ylim(())
axs_action[0].grid(True)
# axs_action[0].xlabel("Step", fontsize=12)
axs_action[0].set_ylabel("LNA\nCurrent (\u00B5A)", fontsize=12)
# axs_action[0].legend([], fontsize=12)
# axs_action[0].xticks(fontsize=10)
axs_action[0].set_yticks(list(range(0, 600, 100)))
axs_action[0].tick_params(axis='both', labelsize=10)
discontinuity_idx = np.diff(mixer_currents).nonzero()[0]
for i in discontinuity_idx:
    axs_action[1].plot([discontinuity_idx + 1, discontinuity_idx + 1], [mixer_currents[discontinuity_idx], mixer_currents[discontinuity_idx + 1]], 'g--')
axs_action[1].plot(heaviside(mixer_currents), 'g')
axs_action[1].set_xlim((0, num_episodes * rf_env.MaxSteps))
# axs_action[1].ylim(())
axs_action[1].grid(True)
axs_action[1].set_xlabel("Step", fontsize=12)
axs_action[1].set_ylabel("Mixer\nCurrent (\u00B5A)", fontsize=12)
# axs_action[1].legend([], fontsize=12)
# axs_action[1].xticks(fontsize=10)
axs_action[1].set_yticks(list(range(0, 500, 100)))
axs_action[1].tick_params(axis='both', labelsize=10)
fig_action.suptitle("RF Front-End Configs", size=14)
plt.show()
fig_action.savefig(os.path.join(save_dir, "FEConfigs_Random.pdf"))
fig_action.savefig(os.path.join(save_dir, "FEConfigs_Random.png"))

plt.figure()
fig_reward, axs_reward = plt.subplots(2, 1, sharex=True)
fig_reward.subplots_adjust(hspace=0)
discontinuity_idx = np.diff(EVMs).nonzero()[0]
for i in discontinuity_idx:
    axs_reward[0].plot([discontinuity_idx + 1, discontinuity_idx + 1], [EVMs[discontinuity_idx], EVMs[discontinuity_idx + 1]], 'r--')
axs_reward[0].plot(heaviside(EVMs), 'r')
axs_reward[0].set_xlim((0, num_episodes * rf_env.MaxSteps))
# axs_reward[0].ylim(())
axs_reward[0].grid(True)
# axs_reward[0].xlabel("Step", fontsize=12)
axs_reward[0].set_ylabel("EVM\n(\%)", fontsize=12)
# axs_reward[0].legend([], fontsize=12)
# axs_reward[0].xticks(fontsize=10)
axs_reward[0].tick_params(axis='both', labelsize=10)
discontinuity_idx = np.diff(powers).nonzero()[0]
for i in discontinuity_idx:
    axs_reward[1].plot([discontinuity_idx + 1, discontinuity_idx + 1], [powers[discontinuity_idx], powers[discontinuity_idx + 1]], 'r--')
axs_reward[1].plot(heaviside(powers), 'r')
axs_reward[1].set_xlim((0, num_episodes * rf_env.MaxSteps))
# axs_reward[1].ylim(())
axs_reward[1].grid(True)
axs_reward[1].set_xlabel("Step", fontsize=12)
axs_reward[1].set_ylabel("Power\n(\u00B5W)", fontsize=12)
# axs_reward[1].legend([], fontsize=12)
# axs_reward[1].xticks(fontsize=10)
axs_reward[1].tick_params(axis='both', labelsize=10)
fig_reward.suptitle("System-Level Performance Metrics", size=14)
plt.show()
fig_reward.savefig(os.path.join(save_dir, "SLPerf_Random.pdf"))
fig_reward.savefig(os.path.join(save_dir, "SLPerf_Random.png"))
# Out:
# <>:174: SyntaxWarning: invalid escape sequence '\%'
# <>:174: SyntaxWarning: invalid escape sequence '\%'
# /tmp/ipykernel_3582467/4198970022.py:174: SyntaxWarning: invalid escape sequence '\%'
#   axs_reward[0].set_ylabel("EVM\n(\%)", fontsize=12)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/mabdi-radiortml/lib/python3.12/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File ~/anaconda3/envs/mabdi-radiortml/lib/python3.12/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     464     kwargs['input'] = empty
# ...

# %%
import scienceplots
import numpy as np

plt.style.use(['science','ieee'])

# %%

num_episodes = 3
cumulative_rewards_test = []
signal_powers = []
snrs = []
EVMs = []
powers = []
BERs = []
EVMs_Normalized = []
powers_Normalized = []
BERs_Normalized = []
lna_currents = []
mixer_currents = []

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, _ = env.reset(keep_last_config=True)
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)

    # print(f"Signal Power: {signal_powers[-1]}\tSNR: {snrs[-1]}")

    cumulative_reward_test = 0

    for t in count():
        signal_powers.append(env.comm_config.SignalPower)
        snrs.append(env.comm_config.SNR)

        with torch.no_grad():
            action = policy_net(state).max(1).indices.view(1, 1)
        observation, reward, terminated, measures = env.step(action.item())
        lna_currents.append(env.getLNACurrent())
        mixer_currents.append(env.getMixerCurrent())

        cumulative_reward_test += reward
        EVMs.append(measures['rmsEVM'])
        powers.append(measures['Power'])
        BERs.append(measures['BER'])
        EVMs_Normalized.append(measures['rmsEVM_Normalized'])
        powers_Normalized.append(measures['Power_Normalized'])
        BERs_Normalized.append(measures['BER'])
        
        done = terminated
        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Move to the next state
        state = next_state

        if done:
            cumulative_rewards_test.append(cumulative_reward_test)
            break

# plt.figure()
# plt.subplot(4, 1, 1)
# plt.plot(lna_currents)
# plt.title("LNA Current")
# plt.subplot(4, 1, 2)
# plt.plot(mixer_currents)
# plt.title("Mixer Current")
# plt.subplot(4, 1, 3)
# plt.plot(EVMs)
# plt.title("EVM")
# plt.subplot(4, 1, 4)
# plt.plot(powers)
# plt.title("Power Consumption")
# plt.show()

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
cumulative_rewards_test = np.array(cumulative_rewards_test, dtype=np.float32)
signal_powers = np.array(signal_powers, dtype=np.float32)
snrs = np.array(snrs, dtype=np.float32)
EVMs = np.array(EVMs, dtype=np.float32)
powers = np.array(powers, dtype=np.float32)
BERs = np.array(BERs, dtype=np.float32)
EVMs_Normalized = np.array(EVMs_Normalized, dtype=np.float32)
powers_Normalized = np.array(powers_Normalized, dtype=np.float32)
BERs_Normalized = np.array(BERs_Normalized, dtype=np.float32)
lna_currents = np.array(lna_currents, dtype=np.float32)
mixer_currents = np.array(mixer_currents, dtype=np.float32)
def heaviside(x):
    x[np.diff(x, prepend=x[0]) != 0] = np.nan
    return x

fig_state = plt.figure()
plt.subplot(2, 1, 1)
discontinuity_idx = np.diff(signal_powers).nonzero()[0]
for i in discontinuity_idx:
    plt.plot([discontinuity_idx + 1, discontinuity_idx + 1], [signal_powers[discontinuity_idx], signal_powers[discontinuity_idx + 1]], 'b--')
plt.plot(heaviside(signal_powers), 'b')
plt.xlim((0, num_episodes * rf_env.MaxSteps))
# plt.ylim(())
plt.grid(True)
# plt.xlabel("Step", fontsize=12)
plt.ylabel("Signal Power\n(dB)", fontsize=12)
# plt.legend([], fontsize=12)
# plt.xticks(fontsize=10)
plt.yticks(rf_env.SignalPower_List, fontsize=10)
plt.subplot(2, 1, 2)
discontinuity_idx = np.diff(snrs).nonzero()[0]
for i in discontinuity_idx:
    plt.plot([discontinuity_idx + 1, discontinuity_idx + 1], [snrs[discontinuity_idx], snrs[discontinuity_idx + 1]], 'b--')
plt.plot(heaviside(snrs), 'b')
plt.xlim((0, num_episodes * rf_env.MaxSteps))
# plt.ylim(())
plt.grid(True)
plt.xlabel("Step", fontsize=12)
plt.ylabel("SNR\n(dB)", fontsize=12)
# plt.legend([], fontsize=12)
# plt.xticks(fontsize=10)
plt.yticks(rf_env.SNR_List, fontsize=10)
plt.rcParams["figure.titlesize"] = 14
plt.suptitle("Communication Environment Params")
plt.show()
fig_state.savefig(os.path.join(save_dir, "CommEnvParams_Random.pdf"))
fig_state.savefig(os.path.join(save_dir, "CommEnvParams_Random.png"))

fig_action = plt.figure()
plt.subplot(2, 1, 1)
discontinuity_idx = np.diff(lna_currents).nonzero()[0]
for i in discontinuity_idx:
    plt.plot([discontinuity_idx + 1, discontinuity_idx + 1], [lna_currents[discontinuity_idx], lna_currents[discontinuity_idx + 1]], 'g--')
plt.plot(heaviside(lna_currents), 'g')
plt.xlim((0, num_episodes * rf_env.MaxSteps))
# plt.ylim(())
plt.grid(True)
# plt.xlabel("Step", fontsize=12)
plt.ylabel("LNA Current\n(\u00B5A)", fontsize=12)
# plt.legend([], fontsize=12)
# plt.xticks(fontsize=10)
plt.yticks(list(range(0, 600, 100)), fontsize=10)
plt.subplot(2, 1, 2)
discontinuity_idx = np.diff(mixer_currents).nonzero()[0]
for i in discontinuity_idx:
    plt.plot([discontinuity_idx + 1, discontinuity_idx + 1], [mixer_currents[discontinuity_idx], mixer_currents[discontinuity_idx + 1]], 'g--')
plt.plot(heaviside(mixer_currents), 'g')
plt.xlim((0, num_episodes * rf_env.MaxSteps))
# plt.ylim(())
plt.grid(True)
plt.xlabel("Step", fontsize=12)
plt.ylabel("Mixer Current\n(\u00B5A)", fontsize=12)
# plt.legend([], fontsize=12)
# plt.xticks(fontsize=10)
plt.yticks(list(range(0, 500, 100)), fontsize=10)
plt.rcParams["figure.titlesize"] = 14
plt.suptitle("RF Front-End Configs")
plt.show()
fig_action.savefig(os.path.join(save_dir, "FEConfigs_Random.pdf"))
fig_action.savefig(os.path.join(save_dir, "FEConfigs_Random.png"))

fig_reward = plt.figure()
plt.subplot(2, 1, 1)
discontinuity_idx = np.diff(EVMs).nonzero()[0]
for i in discontinuity_idx:
    plt.plot([discontinuity_idx + 1, discontinuity_idx + 1], [EVMs[discontinuity_idx], EVMs[discontinuity_idx + 1]], 'r--')
plt.plot(heaviside(EVMs), 'r')
plt.xlim((0, num_episodes * rf_env.MaxSteps))
# plt.ylim(())
plt.grid(True)
# plt.xlabel("Step", fontsize=12)
plt.ylabel("EVM\n(\%)", fontsize=12)
# plt.legend([], fontsize=12)
# plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.subplot(2, 1, 2)
discontinuity_idx = np.diff(powers).nonzero()[0]
for i in discontinuity_idx:
    plt.plot([discontinuity_idx + 1, discontinuity_idx + 1], [powers[discontinuity_idx], powers[discontinuity_idx + 1]], 'r--')
plt.plot(heaviside(powers), 'r')
plt.xlim((0, num_episodes * rf_env.MaxSteps))
# plt.ylim(())
plt.grid(True)
plt.xlabel("Step", fontsize=12)
plt.ylabel("Power\n(\u00B5W)", fontsize=12)
# plt.legend([], fontsize=12)
# plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.rcParams["figure.titlesize"] = 14
plt.suptitle("System-Level Performance Metrics")
plt.show()
fig_reward.savefig(os.path.join(save_dir, "SLPerf_Random.pdf"))
fig_reward.savefig(os.path.join(save_dir, "SLPerf_Random.png"))

# %%
import scienceplots
import numpy as np

plt.style.use(['science','ieee'])

fig = plt.figure()
rewards_t = torch.tensor(cumulative_rewards, dtype=torch.float)
if show_result:
    plt.title('Result')
else:
    plt.clf()
    plt.title('Training...')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')
plt.plot(rewards_t.numpy())
# Take 100 episode averages and plot them too
if len(rewards_t) >= 100:
    means = rewards_t.unfold(0, 100, 1).mean(1).view(-1)
    # means = torch.cat((torch.zeros(99), means))
    plt.plot(means.numpy())

plt.pause(0.001)  # pause a bit so that plots are updated
if is_ipython:
    if not show_result:
        display.display(plt.gcf())
        display.clear_output(wait=True)
    else:
        display.display(plt.gcf())

# %%
import scienceplots
import numpy as np

plt.style.use(['science','ieee'])

# %%

num_episodes = 4
cumulative_rewards_test = []
signal_powers = []
snrs = []
EVMs = []
powers = []
BERs = []
EVMs_Normalized = []
powers_Normalized = []
BERs_Normalized = []
lna_currents = []
mixer_currents = []

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, _ = env.reset(keep_last_config=True)
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)

    # print(f"Signal Power: {signal_powers[-1]}\tSNR: {snrs[-1]}")

    cumulative_reward_test = 0

    for t in count():
        signal_powers.append(env.comm_config.SignalPower)
        snrs.append(env.comm_config.SNR)

        with torch.no_grad():
            action = policy_net(state).max(1).indices.view(1, 1)
        observation, reward, terminated, measures = env.step(action.item())
        lna_currents.append(env.getLNACurrent())
        mixer_currents.append(env.getMixerCurrent())

        cumulative_reward_test += reward
        EVMs.append(measures['rmsEVM'])
        powers.append(measures['Power'])
        BERs.append(measures['BER'])
        EVMs_Normalized.append(measures['rmsEVM_Normalized'])
        powers_Normalized.append(measures['Power_Normalized'])
        BERs_Normalized.append(measures['BER'])
        
        done = terminated
        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Move to the next state
        state = next_state

        if done:
            cumulative_rewards_test.append(cumulative_reward_test)
            break

# plt.figure()
# plt.subplot(4, 1, 1)
# plt.plot(lna_currents)
# plt.title("LNA Current")
# plt.subplot(4, 1, 2)
# plt.plot(mixer_currents)
# plt.title("Mixer Current")
# plt.subplot(4, 1, 3)
# plt.plot(EVMs)
# plt.title("EVM")
# plt.subplot(4, 1, 4)
# plt.plot(powers)
# plt.title("Power Consumption")
# plt.show()

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
cumulative_rewards_test = np.array(cumulative_rewards_test, dtype=np.float32)
signal_powers = np.array(signal_powers, dtype=np.float32)
snrs = np.array(snrs, dtype=np.float32)
EVMs = np.array(EVMs, dtype=np.float32)
powers = np.array(powers, dtype=np.float32)
BERs = np.array(BERs, dtype=np.float32)
EVMs_Normalized = np.array(EVMs_Normalized, dtype=np.float32)
powers_Normalized = np.array(powers_Normalized, dtype=np.float32)
BERs_Normalized = np.array(BERs_Normalized, dtype=np.float32)
lna_currents = np.array(lna_currents, dtype=np.float32)
mixer_currents = np.array(mixer_currents, dtype=np.float32)
def heaviside(x):
    x[np.diff(x, prepend=x[0]) != 0] = np.nan
    return x

fig = plt.figure(figsize=(15, 7))
ax1 = plt.subplot(4, 1, 1)
ax1.plot(heaviside(signal_powers), color=colors[0])
ax1.set_ylabel("Signal Power (dB)", color=colors[0], fontsize=12)
ax1.tick_params(axis="y", labelcolor=colors[0])
ax1.set_yticks(rf_env.SignalPower_List)
ax2 = ax1.twinx()
ax2.plot(heaviside(snrs), color=colors[1])
ax2.set_ylabel("SNR (dB)", color=colors[1], fontsize=12)
ax2.tick_params(axis="y", labelcolor=colors[1])
ax2.set_yticks(rf_env.SNR_List)
plt.subplot(4, 1, 2)
plt.plot(heaviside(lna_currents))
plt.plot(heaviside(mixer_currents))
plt.ylabel("Current (uA)", fontsize=12)
plt.legend(['LNA', 'Mixer'], fontsize=12)
plt.yticks(list(range(0, 600, 100)), fontsize=10)
plt.subplot(4, 1, 3)
plt.plot(heaviside(EVMs_Normalized))
plt.plot(heaviside(powers_Normalized))
plt.plot(heaviside(BERs_Normalized))
plt.ylabel("Normalized Reward", fontsize=12)
plt.legend(['EVM', 'Power', 'BER'], fontsize=12)
ax1 = plt.subplot(4, 1, 4)
ax1.plot(EVMs, color=colors[0])
ax1.set_ylabel("EVM (\%)", color=colors[0], fontsize=12)
ax1.tick_params(axis="y", labelcolor=colors[0])
ax2 = ax1.twinx()
ax2.plot(powers, color=colors[1])
ax2.set_ylabel("Power (uW)", color=colors[1], fontsize=12)
ax2.tick_params(axis="y", labelcolor=colors[1])
# print(f"EVM: min: {min(EVMs)}, max: {max(EVMs)}, range: {max(EVMs) - min(EVMs)}")
# print(f"Power: min: {min(powers)}, max: {max(powers)}, range: {max(powers) - min(powers)}")
plt.show()
fig.savefig(os.path.join(save_dir, "test_results.pdf"))
# Out:
# <>:117: SyntaxWarning: invalid escape sequence '\%'
# <>:117: SyntaxWarning: invalid escape sequence '\%'
# /tmp/ipykernel_3582467/607729753.py:117: SyntaxWarning: invalid escape sequence '\%'
#   ax1.set_ylabel("EVM (\%)", color=colors[0], fontsize=12)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/mabdi-radiortml/lib/python3.12/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File ~/anaconda3/envs/mabdi-radiortml/lib/python3.12/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     464     kwargs['input'] = empty
# ...

# %%
# %%

num_episodes = 4
cumulative_rewards_test = []
signal_powers = []
snrs = []
EVMs = []
powers = []
BERs = []
EVMs_Normalized = []
powers_Normalized = []
BERs_Normalized = []
lna_currents = []
mixer_currents = []

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, _ = env.reset(keep_last_config=True)
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)

    # print(f"Signal Power: {signal_powers[-1]}\tSNR: {snrs[-1]}")

    cumulative_reward_test = 0

    for t in count():
        signal_powers.append(env.comm_config.SignalPower)
        snrs.append(env.comm_config.SNR)

        with torch.no_grad():
            action = policy_net(state).max(1).indices.view(1, 1)
        observation, reward, terminated, measures = env.step(action.item())
        lna_currents.append(env.getLNACurrent())
        mixer_currents.append(env.getMixerCurrent())

        cumulative_reward_test += reward
        EVMs.append(measures['rmsEVM'])
        powers.append(measures['Power'])
        BERs.append(measures['BER'])
        EVMs_Normalized.append(measures['rmsEVM_Normalized'])
        powers_Normalized.append(measures['Power_Normalized'])
        BERs_Normalized.append(measures['BER'])
        
        done = terminated
        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Move to the next state
        state = next_state

        if done:
            cumulative_rewards_test.append(cumulative_reward_test)
            break

# plt.figure()
# plt.subplot(4, 1, 1)
# plt.plot(lna_currents)
# plt.title("LNA Current")
# plt.subplot(4, 1, 2)
# plt.plot(mixer_currents)
# plt.title("Mixer Current")
# plt.subplot(4, 1, 3)
# plt.plot(EVMs)
# plt.title("EVM")
# plt.subplot(4, 1, 4)
# plt.plot(powers)
# plt.title("Power Consumption")
# plt.show()

colors = ["tab:blue", "tab:orange"]

fig = plt.figure(figsize=(20, 7))
ax1 = plt.subplot(4, 1, 1)
ax1.plot(signal_powers, color=colors[0])
ax1.set_ylabel("Signal Power (dB)", color=colors[0])
ax1.tick_params(axis="y", labelcolor=colors[0])
ax1.set_yticks(rf_env.SignalPower_List)
ax2 = ax1.twinx()
ax2.plot(snrs, color=colors[1])
ax2.set_ylabel("SNR (dB)", color=colors[1])
ax2.tick_params(axis="y", labelcolor=colors[1])
ax2.set_yticks(rf_env.SNR_List)
plt.subplot(4, 1, 2)
plt.plot(lna_currents)
plt.plot(mixer_currents)
plt.ylabel("Current (uA)")
plt.legend(['LNA', 'Mixer'])
plt.yticks(list(range(0, 600, 100)))
plt.subplot(4, 1, 3)
plt.plot(EVMs_Normalized)
plt.plot(powers_Normalized)
plt.plot(BERs_Normalized)
plt.ylabel("Normalized Reward")
plt.legend(['EVM', 'Power', 'BER'])
ax1 = plt.subplot(4, 1, 4)
ax1.plot(EVMs, color=colors[0])
ax1.set_ylabel("EVM (%)", color=colors[0])
ax1.tick_params(axis="y", labelcolor=colors[0])
ax2 = ax1.twinx()
ax2.plot(powers, color=colors[1])
ax2.set_ylabel("Power (uW)", color=colors[1])
ax2.tick_params(axis="y", labelcolor=colors[1])
# print(f"EVM: min: {min(EVMs)}, max: {max(EVMs)}, range: {max(EVMs) - min(EVMs)}")
# print(f"Power: min: {min(powers)}, max: {max(powers)}, range: {max(powers) - min(powers)}")
plt.show()
fig.savefig(os.path.join(save_dir, "test_results.pdf"))

# %%
# %%
# For evaluation, improve the communication environment step by step and check the actions
cumulative_rewards_test = []
signal_powers = []
snrs = []
EVMs = []
powers = []
BERs = []
EVMs_Normalized = []
powers_Normalized = []
BERs_Normalized = []
lna_currents = []
mixer_currents = []

# Initialize the environment and get its state
env = rf_env(dataset_dir)
state, _, _, _ = env.improve_comm_env()
state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)

# print(f"Signal Power: {signal_powers[-1]}\tSNR: {snrs[-1]}")

cumulative_reward_test = 0

for t in count():
    signal_powers.append(env.comm_config.SignalPower)
    snrs.append(env.comm_config.SNR)

    with torch.no_grad():
        action = policy_net(state).max(1).indices.view(1, 1)
    observation, reward, terminated, measures = env.improve_comm_env(action.item())
    lna_currents.append(env.getLNACurrent())
    mixer_currents.append(env.getMixerCurrent())

    cumulative_reward_test += reward
    EVMs.append(measures['rmsEVM'])
    powers.append(measures['Power'])
    BERs.append(measures['BER'])
    EVMs_Normalized.append(measures['rmsEVM_Normalized'])
    powers_Normalized.append(measures['Power_Normalized'])
    BERs_Normalized.append(measures['BER'])
    
    done = terminated
    if terminated:
        next_state = None
    else:
        next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

    # Move to the next state
    state = next_state

    if done:
        cumulative_rewards_test.append(cumulative_reward_test)
        break

# plt.figure()
# plt.subplot(4, 1, 1)
# plt.plot(lna_currents)
# plt.title("LNA Current")
# plt.subplot(4, 1, 2)
# plt.plot(mixer_currents)
# plt.title("Mixer Current")
# plt.subplot(4, 1, 3)
# plt.plot(EVMs)
# plt.title("EVM")
# plt.subplot(4, 1, 4)
# plt.plot(powers)
# plt.title("Power Consumption")
# plt.show()

colors = ["tab:blue", "tab:orange"]

fig = plt.figure(figsize=(20, 7))
ax1 = plt.subplot(4, 1, 1)
ax1.plot(signal_powers, color=colors[0])
ax1.set_ylabel("Signal Power (dB)", color=colors[0])
ax1.tick_params(axis="y", labelcolor=colors[0])
ax1.set_yticks(rf_env.SignalPower_List)
ax2 = ax1.twinx()
ax2.plot(snrs, color=colors[1])
ax2.set_ylabel("SNR (dB)", color=colors[1])
ax2.tick_params(axis="y", labelcolor=colors[1])
ax2.set_yticks(rf_env.SNR_List)
plt.subplot(4, 1, 2)
plt.plot(lna_currents)
plt.plot(mixer_currents)
plt.ylabel("Current (uA)")
plt.legend(['LNA', 'Mixer'])
plt.yticks(list(range(0, 600, 100)))
plt.subplot(4, 1, 3)
plt.plot(EVMs_Normalized)
plt.plot(powers_Normalized)
plt.plot(BERs_Normalized)
plt.ylabel("Normalized Reward")
plt.legend(['EVM', 'Power', 'BER'])
ax1 = plt.subplot(4, 1, 4)
ax1.plot(EVMs, color=colors[0])
ax1.set_ylabel("EVM (%)", color=colors[0])
ax1.tick_params(axis="y", labelcolor=colors[0])
ax2 = ax1.twinx()
ax2.plot(powers, color=colors[1])
ax2.set_ylabel("Power (uW)", color=colors[1])
ax2.tick_params(axis="y", labelcolor=colors[1])
# print(f"EVM: min: {min(EVMs)}, max: {max(EVMs)}, range: {max(EVMs) - min(EVMs)}")
# print(f"Power: min: {min(powers)}, max: {max(powers)}, range: {max(powers) - min(powers)}")
plt.show()
fig.savefig(os.path.join(save_dir, "test_results_incremental.pdf"))

# %%
# %%
fig = plt.figure()
cumulative_rewards_t = torch.tensor(cumulative_rewards, device=torch.device('cpu'))
cumulative_rewards_mean = cumulative_rewards_t.unfold(dimension=0, size=100, step=1).mean()
print(cumulative_rewards_t.unfold(dimension=0, size=100, step=1).mean(dim=1))
plt.plot(cumulative_rewards_t.unfold(dimension=0, size=100, step=1).mean(dim=1))
plt.show()
# fig.savefig(os.path.join(save_dir, "test_cumulative_results.pdf"))
